# %%
import os
os.listdir()
# Out:
# ['modules.json', 'importscript.sh', 'Untitled.ipynb', '.ipynb_checkpoints']

# %%
file = open('modules.json')

# %%
import json

# %%
with open('modules.json') as json_data:
    d = json.load(json_data)
    print(json.dumps(d[0], indent=4, sort_keys=True))
# Out:
# {
#     "AcadYear": "2017/2018",
#     "CorsBiddingStats": [
#         {
#             "AcadYear": "2010/2011",
#             "Bidders": "1",
#             "Faculty": "School Of Business",
#             "Group": "Lecture B1",
#             "HighestBid": "300",
#             "LowestBid": "300",
#             "LowestSuccessfulBid": "1",
#             "Quota": "10",
#             "Round": "1A",
#             "Semester": "1",
#             "StudentAcctType": "Returning Students [P]"
#         },
#         {
#             "AcadYear": "2010/2011",
#             "Bidders": "3",
#             "Faculty": "School Of Business",
#             "Group": "Lecture B1",
#             "HighestBid": "102",
#             "LowestBid": "1",
#             "LowestSuccessfulBid": "1",
#             "Quota": "9",
#             "Round": "1B",
#             "Semester": "1",
#             "StudentAcctType": "Returning Students [P]"
#         },
#         {
#             "AcadYear": "2010/2011",
# ...

# %%
file = open('modules.json')
parsed = json.load(file)
print(json.dumps(parsed[0], indent=2, sort_keys=True))
# Out:
# {
#   "AcadYear": "2017/2018",
#   "CorsBiddingStats": [
#     {
#       "AcadYear": "2010/2011",
#       "Bidders": "1",
#       "Faculty": "School Of Business",
#       "Group": "Lecture B1",
#       "HighestBid": "300",
#       "LowestBid": "300",
#       "LowestSuccessfulBid": "1",
#       "Quota": "10",
#       "Round": "1A",
#       "Semester": "1",
#       "StudentAcctType": "Returning Students [P]"
#     },
#     {
#       "AcadYear": "2010/2011",
#       "Bidders": "3",
#       "Faculty": "School Of Business",
#       "Group": "Lecture B1",
#       "HighestBid": "102",
#       "LowestBid": "1",
#       "LowestSuccessfulBid": "1",
#       "Quota": "9",
#       "Round": "1B",
#       "Semester": "1",
#       "StudentAcctType": "Returning Students [P]"
#     },
#     {
#       "AcadYear": "2010/2011",
#       "Bidders": "1",
#       "Faculty": "School Of Business",
#       "Group": "Lecture B1",
#       "HighestBid": "325",
#       "LowestBid": "325",
# ...
